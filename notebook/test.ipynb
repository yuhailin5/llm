# %% [markdown]
# # 测试

# %%
print("hello")
# Out:
# hello

# %%
import numpy as np

arr = np.random.randint(0, 10, size=4)
print(arr)
# Out:
# [6 9 1 0]

# %%
import kagglehub
# Out:
# ...
# ---------------------------------------------------------------------------
# UnauthenticatedError                      Traceback (most recent call last)
# Cell In[3], line 4
#       1 import kagglehub
#       2 kagglehub.login()
#       3
# ----> 4 path = kagglehub.competition_download("titanic")
#       5 print(path)
#       6
#       7
#
# File D:\anaconda_envs\envs\py_learn\Lib\site-packages\kagglehub\competition.py:30, in competition_download(handle, path, force_download, output_dir)
#      28 h = parse_competition_handle(handle)
#      29 logger.info(f"Downloading competition: {h.to_url()} ...", extra={**EXTRA_CONSOLE_BLOCK})
# ---> 30 path, _ = registry.competition_resolver(
#      31     h,
#      32     path,
#      33     force_download=force_download,
#      34     output_dir=output_dir,
#      35 )
#      36 return path
#
# File D:\anaconda_envs\envs\py_learn\Lib\site-packages\kagglehub\registry.py:28, in MultiImplRegistry.__call__(self, *args, **kwargs)
# ...
