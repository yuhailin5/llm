# %%
import kagglehub

# Download latest version
path = kagglehub.competition_download('otto-group-product-classification-challenge')

print("Path to competition files:", path)
# Out:
# ...
# 100%|█████████████████████████████████████████████████████████████████████████████| 6.05M/6.05M [00:00<00:00, 6.38MB/s]
# Extracting files...
# Path to competition files: C:\Users\86191\.cache\kagglehub\competitions\otto-group-product-classification-challenge
